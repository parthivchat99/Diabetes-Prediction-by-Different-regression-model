# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
dbts=pd.read_csv('/diabetes.csv')
dbts
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
dbts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dbts.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
dbts.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dbts.corr(),annot=True,fmt=".3f",cmap="YlGnBu")
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
plt.figure(figsize=(10,8))
kde=sns.kdeplot(dbts["Pregnancies"][dbts["Outcome"]==1],color="Blue",fill=True)
kde=sns.kdeplot(dbts["Pregnancies"][dbts["Outcome"]==0],color="Green",fill=True)
kde.set_xlabel("Pregnancies")
kde.set_ylabel("Density")
kde.legend("Positive","Negative")
plt.title("Distribution of Pregnancies with Outcome")
# Out:
# <ipython-input-12-270eeccfd87c>:6: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   kde.legend("Positive","Negative")
# Text(0.5, 1.0, 'Distribution of Pregnancies with Outcome')

# %%
plt.figure(figsize=(10,8))
kde=sns.kdeplot(dbts["Glucose"][dbts["Outcome"]==1],color="Red",fill=True)
kde=sns.kdeplot(dbts["Glucose"][dbts["Outcome"]==0],color="Yellow",fill=True)
kde.set_xlabel("Glucose")
kde.set_ylabel("Density")
kde.legend("Positive","Negative")
plt.title("Distribution of Glucose with Outcome")
# Out:
# <ipython-input-13-e3810708e883>:6: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   kde.legend("Positive","Negative")
# Text(0.5, 1.0, 'Distribution of Glucose with Outcome')

# %%
X=dbts.drop(columns='Outcome',axis=1)
Y=dbts['Outcome']
print(X)
print(Y)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X)
# Out:
# StandardScaler()

# %%
std_data=scaler.transform(X)
print(std_data)
X=std_data
# Out:
# [[ 0.63994726  0.84832379  0.14964075 ...  0.20401277  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.12339636 -0.16054575 ... -0.68442195 -0.36506078
#   -0.19067191]
#  [ 1.23388019  1.94372388 -0.26394125 ... -1.10325546  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808   0.00330087  0.14964075 ... -0.73518964 -0.68519336
#   -0.27575966]
#  [-0.84488505  0.1597866  -0.47073225 ... -0.24020459 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.8730192   0.04624525 ... -0.20212881 -0.47378505
#   -0.87137393]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.35,stratify=Y,random_state=42)

# %%
print(X.shape,X_train.shape,X_test.shape)
print(Y.shape,Y_train.shape,Y_test.shape)
# Out:
# (768, 8) (499, 8) (269, 8)
# (768,) (499,) (269,)

# %%
from sklearn import svm
classifier=svm.SVC(kernel='linear')
classifier.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
from sklearn.metrics import accuracy_score
X_train_pred=classifier.predict(X_train)
train_data_accu=accuracy_score(X_train_pred,Y_train)
print("Accuracy score of training data: ",train_data_accu)
X_test_pred=classifier.predict(X_test)
test_data_accu=accuracy_score(X_test_pred,Y_test)
print("Accuracy score of testing data: ",test_data_accu)
# Out:
# Accuracy score of training data:  0.7855711422845691
# Accuracy score of testing data:  0.7360594795539034

# %%
import numpy as np
ip_data=(4,211,92,3,0,37.6,0.181,30)
data_np_arr=np.asarray(ip_data)
ip_data_reshape=data_np_arr.reshape(1,-1)
std_ip=scaler.transform(ip_data_reshape)
print(std_ip)

prediction=classifier.predict(std_ip)


if prediction[0]==0:
  print("NON_DIABETIC")
else:
  print("DIABETIC")
# Out:
# [[ 0.04601433  2.82004395  1.18359575 -1.10002803 -0.69289057  0.71168975
#   -0.87848095 -0.27575966]]
# DIABETIC
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=20, criterion="entropy", random_state=0)
classifier.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=20, random_state=0)

# %%
X_train_pred=classifier.predict(X_train)
train_data_accu=accuracy_score(X_train_pred,Y_train)
print("Accuracy score of training data: ",train_data_accu)
# Out:
# Accuracy score of training data:  0.9939879759519038

# %%
X_test_pred=classifier.predict(X_test)
test_data_accu=accuracy_score(X_test_pred,Y_test)
print("Accuracy score of testing data: ",test_data_accu)
# Out:
# Accuracy score of testing data:  0.7174721189591078

# %%
import numpy as np
ip_data=(4,211,92,3,0,37.6,0.181,30)
data_np_arr=np.asarray(ip_data)
ip_data_reshape=data_np_arr.reshape(1,-1)
std_ip=scaler.transform(ip_data_reshape)
print(std_ip)

prediction=classifier.predict(std_ip)


if prediction[0]==0:
  print("NON_DIABETIC")
else:
  print("DIABETIC")
# Out:
# [[ 0.04601433  2.82004395  1.18359575 -1.10002803 -0.69289057  0.71168975
#   -0.87848095 -0.27575966]]
# DIABETIC
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
